# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../arranged_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id  limit_bal  sex  education  marriage  age  pay_september  \
# 0           2   1      20000    2          2         1   24              2
# 1           3   2     120000    2          2         2   26             -1
# 2           4   3      90000    2          2         2   34              0
# 3           5   4      50000    2          2         1   37              0
# 4           6   5      50000    1          2         1   57             -1
#
#    pay_august  pay_july   ...     bill_june  bill_may  bill_april  \
# 0           2        -1   ...             0         0           0
# 1           2         0   ...          3272      3455        3261
# 2           0         0   ...         14331     14948       15549
# 3           0         0   ...         28314     28959       29547
# 4           0        -1   ...         20940     19146       19131
#
#    pay_amt_september  pay_amt_august  pay_amt_july  pay_amt_june  pay_amt_may  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0            id       limit_bal           sex     education  \
# count  30000.000000  30000.000000    30000.000000  30000.000000  30000.000000
# mean   15001.500000  15000.500000   167484.322667      1.603733      1.853133
# std     8660.398374   8660.398374   129747.661567      0.489129      0.790349
# min        2.000000      1.000000    10000.000000      1.000000      0.000000
# 25%     7501.750000   7500.750000    50000.000000      1.000000      1.000000
# 50%    15001.500000  15000.500000   140000.000000      2.000000      2.000000
# 75%    22501.250000  22500.250000   240000.000000      2.000000      2.000000
# max    30001.000000  30000.000000  1000000.000000      2.000000      6.000000
#
#            marriage           age  pay_september    pay_august      pay_july  \
# count  30000.000000  30000.000000   30000.000000  30000.000000  30000.000000
# mean       1.551867     35.485500      -0.016700     -0.133767     -0.166200
# ...

# %%
'''
Finding out significance of marriage in default and correlation between marraige & default rate
'''

marriage_default = df[['marriage', 'default']]

print (marriage_default.head())

print ('************')
print ('Correlation between Marriage & default')
print (marriage_default.corr())
print ('************')


print ('Crosstab between Marriage & default')
marriage_cross_tab = pd.crosstab(marriage_default['default'], marriage_default['marriage'])
print marriage_cross_tab
# Out:
#    marriage  default
# 0         1        1
# 1         2        1
# 2         2        0
# 3         1        0
# 4         1        0
# ************
# Correlation between Marriage & default
#           marriage   default
# marriage  1.000000 -0.024339
# default  -0.024339  1.000000
# ************
# Crosstab between Marriage & default
# marriage   0      1      2    3
# default
# 0         49  10453  12623  239
# 1          5   3206   3341   84

# %%
marriage_cross_tab.plot(kind='bar', stacked=True)
plt.show()

# %%
'''
Finding out significance of gender in default and correlation between marraige & default rate
'''

gender_default = df[['sex', 'default']]

print (gender_default.head())

print ('')
print ('')

print ('************')
print ('Correlation between gender & default')
print (gender_default.corr())
print ('************')

print ('')
print ('')
print ('Crosstab between Marriage & default')
gender_cross_tab = pd.crosstab(gender_default['default'], gender_default['sex'])
print gender_cross_tab
# Out:
#    sex  default
# 0    2        1
# 1    2        1
# 2    2        0
# 3    2        0
# 4    1        0
#
#
# ************
# Correlation between gender & default
#               sex   default
# sex      1.000000 -0.039961
# default -0.039961  1.000000
# ************
#
#
# Crosstab between Marriage & default
# sex         1      2
# default
# 0        9015  14349
# 1        2873   3763

# %%
gender_cross_tab.plot(kind='bar', stacked=True)
plt.show()

# %%
'''
Finding out significance of gender in default and correlation between marraige & default rate
'''

education_default = df[['education', 'default']]

print (education_default.head())

print ('')
print ('')

print ('************')
print ('Correlation between education & default')
print (education_default.corr())
print ('************')

print ('')
print ('')
print ('Crosstab between education & default')
education_cross_tab = pd.crosstab(education_default['default'], education_default['education'])
print education_cross_tab
# Out:
#    education  default
# 0          2        1
# 1          2        1
# 2          2        0
# 3          2        0
# 4          2        0
#
#
# ************
# Correlation between education & default
#            education   default
# education   1.000000  0.028006
# default     0.028006  1.000000
# ************
#
#
# Crosstab between education & default
# education   0     1      2     3    4    5   6
# default
# 0          14  8549  10700  3680  116  262  43
# 1           0  2036   3330  1237    7   18   8

# %%
education_cross_tab.plot(kind='bar', stacked=True)
plt.show()
