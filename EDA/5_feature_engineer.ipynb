# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../arranged_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id  limit_bal  sex  education  marriage  age  pay_september  \
# 0           2   1      20000    2          2         1   24              2
# 1           3   2     120000    2          2         2   26             -1
# 2           4   3      90000    2          2         2   34              0
# 3           5   4      50000    2          2         1   37              0
# 4           6   5      50000    1          2         1   57             -1
#
#    pay_august  pay_july   ...     bill_june  bill_may  bill_april  \
# 0           2        -1   ...             0         0           0
# 1           2         0   ...          3272      3455        3261
# 2           0         0   ...         14331     14948       15549
# 3           0         0   ...         28314     28959       29547
# 4           0        -1   ...         20940     19146       19131
#
#    pay_amt_september  pay_amt_august  pay_amt_july  pay_amt_june  pay_amt_may  \
# ...

# %%
df[['pay_september', 'pay_august', 'pay_july', 'pay_june', 'pay_may','pay_april']].agg('mode')
# Out:
#    pay_september  pay_august  pay_july  pay_june  pay_may  pay_april
# 0              0           0         0         0        0          0

# %%
df[['age']].agg('mode')
# Out:
#    age
# 0   29

# %%
df.agg('mode')
# Out:
#        Unnamed: 0     id  limit_bal  sex  education  marriage   age  \
# 0               2      1    50000.0  2.0        2.0       2.0  29.0
# 1               3      2        NaN  NaN        NaN       NaN   NaN
# 2               4      3        NaN  NaN        NaN       NaN   NaN
# 3               5      4        NaN  NaN        NaN       NaN   NaN
# 4               6      5        NaN  NaN        NaN       NaN   NaN
# 5               7      6        NaN  NaN        NaN       NaN   NaN
# 6               8      7        NaN  NaN        NaN       NaN   NaN
# 7               9      8        NaN  NaN        NaN       NaN   NaN
# 8              10      9        NaN  NaN        NaN       NaN   NaN
# 9              11     10        NaN  NaN        NaN       NaN   NaN
# 10             12     11        NaN  NaN        NaN       NaN   NaN
# 11             13     12        NaN  NaN        NaN       NaN   NaN
# 12             14     13        NaN  NaN        NaN       NaN   NaN
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  id  limit_bal  sex  education  marriage  age  pay_september  \
# 0           2   1      20000    2          2         1   24              2
# 1           3   2     120000    2          2         2   26             -1
# 2           4   3      90000    2          2         2   34              0
# 3           5   4      50000    2          2         1   37              0
# 4           6   5      50000    1          2         1   57             -1
#
#    pay_august  pay_july   ...     bill_june  bill_may  bill_april  \
# 0           2        -1   ...             0         0           0
# 1           2         0   ...          3272      3455        3261
# 2           0         0   ...         14331     14948       15549
# 3           0         0   ...         28314     28959       29547
# 4           0        -1   ...         20940     19146       19131
#
#    pay_amt_september  pay_amt_august  pay_amt_july  pay_amt_june  pay_amt_may  \
# ...
